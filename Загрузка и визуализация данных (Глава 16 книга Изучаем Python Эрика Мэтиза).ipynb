# %% [markdown]
# ## Глава 16 `Загрузка данных`

# %%
#'sitka_weather_07-2014.csv'

# %%
import csv # модуль для чтения csv
filename = 'sitka_weather_07-2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    print(header_row)
# Out:
# ['AKDT', 'Max TemperatureF', 'Mean TemperatureF', 'Min TemperatureF', 'Max Dew PointF', 'MeanDew PointF', 'Min DewpointF', 'Max Humidity', ' Mean Humidity', ' Min Humidity', ' Max Sea Level PressureIn', ' Mean Sea Level PressureIn', ' Min Sea Level PressureIn', ' Max VisibilityMiles', ' Mean VisibilityMiles', ' Min VisibilityMiles', ' Max Wind SpeedMPH', ' Mean Wind SpeedMPH', ' Max Gust SpeedMPH', 'PrecipitationIn', ' CloudCover', ' Events', ' WindDirDegrees']

# %%
#import csv # модуль для чтения csv
filename = 'sitka_weather_07-2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    for index, column_header in enumerate(header_row):
        print(index, column_header)
# Out:
# 0 AKDT
# 1 Max TemperatureF
# 2 Mean TemperatureF
# 3 Min TemperatureF
# 4 Max Dew PointF
# 5 MeanDew PointF
# 6 Min DewpointF
# 7 Max Humidity
# 8  Mean Humidity
# 9  Min Humidity
# 10  Max Sea Level PressureIn
# 11  Mean Sea Level PressureIn
# 12  Min Sea Level PressureIn
# 13  Max VisibilityMiles
# 14  Mean VisibilityMiles
# 15  Min VisibilityMiles
# 16  Max Wind SpeedMPH
# 17  Mean Wind SpeedMPH
# 18  Max Gust SpeedMPH
# 19 PrecipitationIn
# 20  CloudCover
# 21  Events
# 22  WindDirDegrees

# %%
# ценная информация в столбцах 0 и 1. Извлечем ее

# %%
# синтаксис для построения нумерованных списков
a = [2,4,6,8, 'foo']
for index, b in enumerate(a):
    print(index, b)
# Out:
# 0 2
# 1 4
# 2 6
# 3 8
# 4 foo

# %%
# сделаем список строковых значений максимальной температуры (позиция [1] = вторая в строке)
# import csv
filename = 'sitka_weather_07-2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    highs = []
    for row in reader: #цикл идет со второй строки, т.к. первую строку (заголовки) уже прошли методом next()
        highs.append(row[1])
        
print(highs)
# Out:
# ['64', '71', '64', '59', '69', '62', '61', '55', '57', '61', '57', '59', '57', '61', '64', '61', '59', '63', '60', '57', '69', '63', '62', '59', '57', '57', '61', '59', '61', '61', '66']

# %%
# нам нужен список численных значений, чтобы передать его в matplotlib
# import csv
filename = 'sitka_weather_07-2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    highs = []
    for row in reader: 
        highs.append(int(row[1]))
        
print(highs)
# Out:
# [64, 71, 64, 59, 69, 62, 61, 55, 57, 61, 57, 59, 57, 61, 64, 61, 59, 63, 60, 57, 69, 63, 62, 59, 57, 57, 61, 59, 61, 61, 66]

# %%
# визуализируем это
from matplotlib import pyplot as plt

# %%
fig = plt.figure(dpi=128, figsize=(10,6))
plt.plot(highs, c='red')

# %%
#форматируем диаграмму
fig = plt.figure(dpi=128, figsize=(10,6))
plt.plot(highs, c='red')
plt.title('Максимальные дневные температуры за июль 2014', fontsize=20)
plt.xlabel('Число месяца', fontsize=10)
plt.ylabel('Температура (F)', fontsize=10)
plt.tick_params(axis='both', which = 'major', labelsize=12)
plt.show()

# %%
#посмотрим на датасет
import pandas as pd

# %%
sitka_weather_df = pd.read_csv('sitka_weather_07-2014.csv')

# %%
sitka_weather_df.head()
# Out:
#        AKDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2014-7-1                64                 56                50
# 1  2014-7-2                71                 62                55
# 2  2014-7-3                64                 58                53
# 3  2014-7-4                59                 56                52
# 4  2014-7-5                69                 59                50
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              53              51             48            96
# 1              55              52             46            96
# 2              55              53             51            97
# 3              52              51             50            96
# 4              52              50             46            96
#
#     Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 0              83             58       ...                           10
# ...

# %%
#импортируем datetime для работы с датами
from datetime import datetime
first_date = datetime.strptime('2014-7-1', '%Y-%m-%d')
print(first_date)
# Out:
# 2014-07-01 00:00:00

# %%
#извлечем даты
#import csv
#from datetime import datetime
#from matplotlib import pyplot as plt
filename = 'sitka_weather_07-2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    dates, highs = [], []
    for row in reader:
        current_date = datetime.strptime(row[0], '%Y-%m-%d')
        dates.append(current_date)
        high = int(row[1])
        highs.append(high)
        
fig = plt.figure(dpi=128, figsize=(10,6))
plt.plot(dates, highs, c='red')
plt.title('Максимальные дневные температуры за июль 2014', fontsize=20)
plt.xlabel('', fontsize=10)
fig.autofmt_xdate()
plt.ylabel('Температура (F)', fontsize=10)
plt.tick_params(axis='both', which = 'major', labelsize=12)
plt.show()

# %%
# погода за год. Новый файл
sitka_weather_2014_df = pd.read_csv('sitka_weather_2014.csv')
sitka_weather_2014_df.head()
# Out:
#        AKST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2014-1-1                46                 42                37
# 1  2014-1-2                41                 38                35
# 2  2014-1-3                39                 36                34
# 3  2014-1-4                43                 38                34
# 4  2014-1-5                44                 42                41
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              40              38             36            97
# 1              38              35             32            97
# 2              38              36             33           100
# 3              35              33             31            97
# 4              42              36             32            97
#
#     Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 0              86             76       ...                           10
# ...

# %%
filename = 'sitka_weather_2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    dates, highs = [], []
    for row in reader:
        current_date = datetime.strptime(row[0], '%Y-%m-%d')
        dates.append(current_date)
        high = int(row[1])
        highs.append(high)
        
fig = plt.figure(dpi=128, figsize=(10,6))
plt.plot(dates, highs, c='red')
plt.title('Максимальные дневные температуры за 2014 год', fontsize=20)
plt.xlabel('', fontsize=10)
fig.autofmt_xdate()
plt.ylabel('Температура (F)', fontsize=10)
plt.tick_params(axis='both', which = 'major', labelsize=12)
plt.show()

# %%
# на одном графике нарисуем минимумы и максимумы температур
filename = 'sitka_weather_2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    dates, highs, lows = [], [], []
    for row in reader:
        current_date = datetime.strptime(row[0], '%Y-%m-%d')
        dates.append(current_date)
        high = int(row[1])
        highs.append(high)
        low = int(row[3])
        lows.append(low)
        
fig = plt.figure(dpi=128, figsize=(10,6))
plt.plot(dates, highs, c='red')
plt.plot(dates, lows, c='blue')
plt.title('Максимальные и минимальные дневные температуры за 2014 год', fontsize=20)
plt.xlabel('', fontsize=25)
fig.autofmt_xdate()
plt.ylabel('Температура (F)', fontsize=10)
plt.tick_params(axis='both', which = 'major', labelsize=12)

plt.show()

# %%
# заштрихуем разницу дневных температур
filename = 'sitka_weather_2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    dates, highs, lows = [], [], []
    for row in reader:
        current_date = datetime.strptime(row[0], '%Y-%m-%d')
        dates.append(current_date)
        high = int(row[1])
        highs.append(high)
        low = int(row[3])
        lows.append(low)
        
fig = plt.figure(dpi=128, figsize=(10,6))
plt.plot(dates, highs, c='red', alpha=0.5) # alpha определяет степень прозрачности вывода
plt.plot(dates, lows, c='blue', alpha=0.5) # чем alpha ближе к 1, тем непрозрачнее
plt.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1) # затушевываем диапазон. Первый аргумент (dates) передается для х
plt.title('Максимальные и минимальные дневные температуры за 2014 год', fontsize=20)
plt.xlabel('', fontsize=25)
fig.autofmt_xdate()
plt.ylabel('Температура (F)', fontsize=10)
plt.tick_params(axis='both', which = 'major', labelsize=12)

plt.show()

# %%
# исследуем датафрейм с пропущенными значениями (death_valley_2014.csv)
death_valley_2014_df = pd.read_csv('death_valley_2014.csv')
death_valley_2014_df.head(5)
# Out:
#         PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2014-1-1              63.0               42.0              24.0
# 1  2014-1-2              66.0               47.0              28.0
# 2  2014-1-3              64.0               46.0              28.0
# 3  2014-1-4              66.0               47.0              28.0
# 4  2014-1-5              61.0               44.0              26.0
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0            14.0             9.0            5.0          48.0
# 1            22.0            19.0           16.0          58.0
# 2            24.0            21.0           15.0          61.0
# 3            25.0            21.0           16.0          61.0
# 4            18.0             7.0           -1.0          56.0
#
#     Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 0            32.0           15.0       ...                          NaN
# ...

# %%
# завершится ошибкой
filename = 'death_valley_2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    dates, highs, lows = [], [], []
    for row in reader:
        current_date = datetime.strptime(row[0], '%Y-%m-%d')
        dates.append(current_date)
        high = int(row[1])
        highs.append(high)
        low = int(row[3])
        lows.append(low)
        
fig = plt.figure(dpi=128, figsize=(10,6))
plt.plot(dates, highs, c='red', alpha=0.5) # alpha определяет степень прозрачности вывода
plt.plot(dates, lows, c='blue', alpha=0.5) # чем alpha ближе к 1, тем непрозрачнее
plt.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1) # затушевываем диапазон. Первый аргумент (dates) передается для х
plt.title('Максимальные и минимальные дневные температуры за 2014 год', fontsize=20)
plt.xlabel('', fontsize=25)
fig.autofmt_xdate()
plt.ylabel('Температура (F)', fontsize=10)
plt.tick_params(axis='both', which = 'major', labelsize=12)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-483-307d73c354c1> in <module>()
#       8         current_date = datetime.strptime(row[0], '%Y-%m-%d')
#       9         dates.append(current_date)
# ---> 10         high = int(row[1])
#      11         highs.append(high)
#      12         low = int(row[3])
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# пустая строка
death_valley_2014_df[death_valley_2014_df['PST'] == "2014-2-16"]
# Out:
#           PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 46  2014-2-16               NaN                NaN               NaN
#
#     Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 46             NaN             NaN            NaN           NaN
#
#      Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 46             NaN            NaN       ...                          NaN
#
#      Mean VisibilityMiles   Min VisibilityMiles   Max Wind SpeedMPH  \
# 46                    NaN                   NaN                 NaN
#
#      Mean Wind SpeedMPH   Max Gust SpeedMPH  PrecipitationIn   CloudCover  \
# 46                  NaN                 NaN              0.0          NaN
#
#      Events   WindDirDegrees
# 46      NaN               -1
#
# [1 rows x 23 columns]

# %%
# обработаем исключение припомощи try-except
filename = 'death_valley_2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    dates, highs, lows = [], [], []
    for row in reader:
        try:
            current_date = datetime.strptime(row[0], '%Y-%m-%d')
            high = int(row[1])
            low = int(row[3])
        except ValueError:
            print(current_date, 'missing data')
        else:
            dates.append(current_date)
            highs.append(high)
            lows.append(low)
        
fig = plt.figure(dpi=128, figsize=(10,6))
plt.plot(dates, highs, c='red', alpha=0.5) 
plt.plot(dates, lows, c='blue', alpha=0.5) 
plt.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1) 
title = 'Максимальные и минимальные дневные температуры\nв Долине смерти за 2014 год'
plt.title(title, fontsize=20)
plt.xlabel('', fontsize=25)
fig.autofmt_xdate()
plt.ylabel('Температура (F)', fontsize=10)
plt.tick_params(axis='both', which = 'major', labelsize=12)

plt.show()
# Out:
# 2014-02-16 00:00:00 missing data

# %% [markdown]
# ## Упражнения 16-1 - 16-4

# %%
# исследуем другой датафрейм
weather_df = pd.read_csv('WeatherSeattle20052017.csv')
weather_df.head(5)
# Out:
#         DATE  PRCP  TMAX  TMIN   RAIN
# 0  2/01/2005  0.00    41    30  False
# 1  3/01/2005  0.00    40    28  False
# 2  4/01/2005  0.00    40    28  False
# 3  5/01/2005  0.00    39    24  False
# 4  6/01/2005  0.17    40    26   True

# %%
import csv
from datetime import datetime
from matplotlib import pyplot as plt
import pandas as pd

# %%
filename_2 = 'WeatherSeattle20052017.csv'
with open(filename_2) as f_2:
    reader_2 = csv.reader(f_2)
    header_row_2 = next(reader_2)
    print(header_row_2)
# Out:
# ['DATE', 'PRCP', 'TMAX', 'TMIN', 'RAIN']

# %%
with open(filename_2) as f_2:
    reader_2 = csv.reader(f_2)
    header_row_2 = next(reader_2)
    highs_2, lows_2, dates_2 = [], [], []
        
    for row in reader_2: 
        highs_2.append(int(row[2]))
        lows_2.append(int(row[3]))
        current_date_2 = datetime.strptime(row[0], '%d/%m/%Y')
        dates_2.append(current_date_2)

fig = plt.figure(dpi=128, figsize=(10,6))
plt.plot(dates_2[3286:3651], highs_2[3286:3651], c='red', alpha=0.5)
plt.plot(dates_2[3286:3651], lows_2[3286:3651], c='blue', alpha=0.5)
plt.fill_between(dates_2[3286:3651], highs_2[3286:3651], lows_2[3286:3651], facecolor='yellow', alpha=0.3)

plt.title('Дневные температуры 2014 год\nСиэтл', fontsize=20)
plt.xlabel('', fontsize=10)
fig.autofmt_xdate()

plt.ylabel('Температура (F)', fontsize=10)
plt.tick_params(axis='both', which = 'major', labelsize=12)
plt.axis([datetime(2014, 1, 1, 0, 0), datetime(2015, 1, 1, 0, 0), 0, 100])

plt.show()

# %%
# обработаем исключение припомощи try-except
filename = 'death_valley_2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    dates, highs, lows = [], [], []
    for row in reader:
        try:
            current_date = datetime.strptime(row[0], '%Y-%m-%d')
            high = int(row[1])
            low = int(row[3])
        except ValueError:
            print(current_date, 'missing data')
        else:
            dates.append(current_date)
            highs.append(high)
            lows.append(low)
        
fig = plt.figure(dpi=128, figsize=(10,6))
plt.plot(dates, highs, c='red', alpha=0.5) 
plt.plot(dates, lows, c='blue', alpha=0.5) 
plt.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1) 
title = 'Максимальные и минимальные дневные температуры\nв Долине смерти за 2014 год'
plt.title(title, fontsize=20)
plt.xlabel('', fontsize=25)
fig.autofmt_xdate()
plt.ylabel('Температура (F)', fontsize=10)
plt.tick_params(axis='both', which = 'major', labelsize=12)

plt.show()
# Out:
# 2014-02-16 00:00:00 missing data

# %%
fig = plt.figure(dpi=128, figsize=(10,6))
#plt.plot(dates, highs, c='red', alpha=0.5) 
#plt.plot(dates, lows, c='blue', alpha=0.5) 
#plt.plot(dates_2[3286:3651], highs_2[3286:3651], c='red', alpha=0.5)
#plt.plot(dates_2[3286:3651], lows_2[3286:3651], c='blue', alpha=0.5)

plt.fill_between(dates, highs, lows, facecolor='red', alpha=0.1) 
plt.fill_between(dates_2[3286:3651], highs_2[3286:3651], lows_2[3286:3651], facecolor='green', alpha=0.3)

title = 'Максимальные и минимальные дневные температуры\nв Долине смерти и Сиэтле за 2014 год'
plt.title(title, fontsize=20)
plt.xlabel('', fontsize=25)
fig.autofmt_xdate()
plt.ylabel('Температура (F)', fontsize=10)
plt.tick_params(axis='both', which = 'major', labelsize=12)
plt.axis([datetime(2014, 1, 1, 0, 0), datetime(2015, 1, 1, 0, 0), 0, 120])

plt.legend ( ("Долина смерти", "Сиэтл") ) # содадим легенду

plt.show()

# %%
# исследуем осадки в Долине смерти
death_valley_2014_df = pd.read_csv('death_valley_2014.csv')
death_valley_2014_df.head(5)
# Out:
#         PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2014-1-1              63.0               42.0              24.0
# 1  2014-1-2              66.0               47.0              28.0
# 2  2014-1-3              64.0               46.0              28.0
# 3  2014-1-4              66.0               47.0              28.0
# 4  2014-1-5              61.0               44.0              26.0
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0            14.0             9.0            5.0          48.0
# 1            22.0            19.0           16.0          58.0
# 2            24.0            21.0           15.0          61.0
# 3            25.0            21.0           16.0          61.0
# 4            18.0             7.0           -1.0          56.0
#
#     Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 0            32.0           15.0       ...                          NaN
# ...

# %%
# посмотрим на столбцы. Осадки - столбец 19 PrecipitationIn
filename = 'death_valley_2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    for index, column_header in enumerate(header_row):
        print(index, column_header)
# Out:
# 0 PST
# 1 Max TemperatureF
# 2 Mean TemperatureF
# 3 Min TemperatureF
# 4 Max Dew PointF
# 5 MeanDew PointF
# 6 Min DewpointF
# 7 Max Humidity
# 8  Mean Humidity
# 9  Min Humidity
# 10  Max Sea Level PressureIn
# 11  Mean Sea Level PressureIn
# 12  Min Sea Level PressureIn
# 13  Max VisibilityMiles
# 14  Mean VisibilityMiles
# 15  Min VisibilityMiles
# 16  Max Wind SpeedMPH
# 17  Mean Wind SpeedMPH
# 18  Max Gust SpeedMPH
# 19 PrecipitationIn
# 20  CloudCover
# 21  Events
# 22  WindDirDegrees

# %%
#проверим типы данных
death_valley_2014_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 23 columns):
# PST                           360 non-null object
# Max TemperatureF              359 non-null float64
# Mean TemperatureF             359 non-null float64
# Min TemperatureF              359 non-null float64
# Max Dew PointF                359 non-null float64
# MeanDew PointF                359 non-null float64
# Min DewpointF                 359 non-null float64
# Max Humidity                  359 non-null float64
#  Mean Humidity                359 non-null float64
#  Min Humidity                 359 non-null float64
#  Max Sea Level PressureIn     359 non-null float64
#  Mean Sea Level PressureIn    359 non-null float64
#  Min Sea Level PressureIn     359 non-null float64
#  Max VisibilityMiles          355 non-null float64
#  Mean VisibilityMiles         355 non-null float64
#  Min VisibilityMiles          355 non-null float64
# ...

# %%
# Соберем данные для диаграммы
# проверим отсутствие данных. Обработаем исключение припомощи try-except
filename = 'death_valley_2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    precipitations, dates, highes = [], [], []
    for row in reader:
        try:
            current_date = datetime.strptime(row[0], '%Y-%m-%d')
            precipitation = float(row[19])
            high = int(row[1])
            
        except ValueError:
            print(current_date, 'missing data')
        else:
            dates.append(current_date)
            precipitations.append(precipitation)
            highes.append(high)
# Out:
# 2014-02-16 00:00:00 missing data

# %%
death_valley_2014_df[death_valley_2014_df['PST'] == "2014-2-16"]
# Out:
#           PST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 46  2014-2-16               NaN                NaN               NaN
#
#     Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 46             NaN             NaN            NaN           NaN
#
#      Mean Humidity   Min Humidity       ...          Max VisibilityMiles  \
# 46             NaN            NaN       ...                          NaN
#
#      Mean VisibilityMiles   Min VisibilityMiles   Max Wind SpeedMPH  \
# 46                    NaN                   NaN                 NaN
#
#      Mean Wind SpeedMPH   Max Gust SpeedMPH  PrecipitationIn   CloudCover  \
# 46                  NaN                 NaN              0.0          NaN
#
#      Events   WindDirDegrees
# 46      NaN               -1
#
# [1 rows x 23 columns]

# %%
# будем исследовать с марта по май (весенние месяцы)
start_date = death_valley_2014_df[death_valley_2014_df['PST'] == "2014-3-1"].index[0]
start_date
# Out:
# 58

# %%
end_date = death_valley_2014_df[death_valley_2014_df['PST'] == "2014-8-30"].index[0]
end_date
# Out:
# 239

# %%
filename = 'death_valley_2014.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    precipitations, dates, highes = [], [], []
    for row in reader:
        try:
            current_date = datetime.strptime(row[0], '%Y-%m-%d')
            precipitation = float(row[19])
            high = int(row[1])
            
        except ValueError:
            print(current_date, 'missing data')
        else:
            dates.append(current_date)
            precipitations.append(precipitation)
            highes.append(high)
        
fig = plt.figure(dpi=128, figsize=(10,6))
plt.plot(dates[start_date:end_date+1], precipitations[start_date:end_date+1], c='blue')
plt.title('Осадки с марта по август в Долине смерти\n2014 год', fontsize=20)
plt.xlabel('', fontsize=10)
fig.autofmt_xdate()
plt.ylabel('Осадки (мм)', fontsize=10)
plt.tick_params(axis='both', which = 'major', labelsize=12)
plt.show()
# Out:
# 2014-02-16 00:00:00 missing data

# %%
# посмотрим еще файлс численностью мирового населения 'population.csv'

# %%
! pip install datapackage

# %%
from datapackage import Package

package = Package('https://datahub.io/core/population-global-historical/datapackage.json')

# print list of all resources:
print(package.resource_names)

# print processed tabular data (if exists any)
for resource in package.resources:
    if resource.descriptor['datahub']['type'] == 'derived/csv':
        print(resource.read())
# Out:
# ['validation_report', 'population_csv', 'population_json', 'population-global-historical_zip', 'population']
# ...

# %%
# 
population_df = pd.read_csv('population.csv')
population_df.head(5)
# Out:
#       Year  Average  Deevey  McEvedy and Jones 1978  Durand Low  Durand High  \
# 0 -1000000    0.125   0.125                     NaN         NaN          NaN
# 1  -300000    1.000   1.000                     NaN         NaN          NaN
# 2   -25000    3.340   3.340                     NaN         NaN          NaN
# 3   -10000    4.000     NaN                     4.0         NaN          NaN
# 4    -8000    5.320   5.320                     NaN         NaN          NaN
#
#    Clark  Biraben  Blaxter  UN  Kremer
# 0    NaN      NaN      NaN NaN     NaN
# 1    NaN      NaN      NaN NaN     NaN
# 2    NaN      NaN      NaN NaN     NaN
# 3    NaN      NaN      NaN NaN     NaN
# 4    NaN      NaN      NaN NaN     NaN

# %%
col = ['Year', 'Average']
population_df[col]
# Out:
#        Year      Average
# 0  -1000000     0.125000
# 1   -300000     1.000000
# 2    -25000     3.340000
# 3    -10000     4.000000
# 4     -8000     5.320000
# 5     -5000    22.500000
# 6     -4000    46.750000
# 7     -3000    14.000000
# 8     -2000    27.000000
# 9     -1600    70.000000
# 10    -1000    50.000000
# 11     -800   100.000000
# 12     -500   100.000000
# 13     -400   157.500000
# 14     -200   202.000000
# 15        1   235.000000
# 16       14   256.000000
# 17      200   234.333333
# 18      350   254.000000
# 19      400   200.666667
# 20      500   198.500000
# 21      600   212.750000
# 22      700   207.666667
# 23      800   232.250000
# 24      900   229.333333
# 25     1000   278.666667
# 26     1100   306.666667
# 27     1200   386.000000
# 28     1250   417.000000
# 29     1300   407.666667
# 30     1340   410.000000
# 31     1400   366.333333
# 32     1500   458.833333
# 33     1600   550.000000
# 34     1650   535.333333
# 35     1700   652.500000
# ...

# %%
filename3 = 'population.csv'
with open(filename3) as f3:
    reader3 = csv.reader(f3)
    header_row3 = next(reader3)
    dates3, amounts3 = [], []
    for row in reader3:
        date3 = int(row[0])
        dates3.append(date3)
        amount3 = float(row[1])
        amounts3.append(amount3)
        
fig = plt.figure(dpi=128, figsize=(10,6))
plt.plot(dates3[15:], amounts3[15:], c='red')
plt.title('Численность', fontsize=20)
plt.xlabel('', fontsize=10)
fig.autofmt_xdate()
plt.ylabel('Численность (млн чел)', fontsize=10)
plt.tick_params(axis='both', which = 'major', labelsize=12)
#plt.scatter(dates3[15:],amounts3[15:], edgecolor='none', s=40, c=amounts3[15:]) 

plt.show()

# %%
! pip install --user pygal

# %%
import pygal

# %%
hist = pygal.Bar()
hist.title = "Population"
hist.x_labels = dates3[15:]
hist.x_title = "Год"
hist.y_title = "Численность мирового населения, млн чел."
hist.add('population', amounts3[15:])
hist.render_to_file('population1.svg')

# %% [markdown]
# # Загрузка `JSON`

# %%
import json

# %%
population_data_df = pd.read_json('population_data.json')
population_data_df.head(5)
# Out:
#   Country Code Country Name        Value  Year
# 0          ARB   Arab World   96388069.0  1960
# 1          ARB   Arab World   98882541.4  1961
# 2          ARB   Arab World  101474075.8  1962
# 3          ARB   Arab World  104169209.2  1963
# 4          ARB   Arab World  106978104.6  1964

# %%
filename = 'population_data.json'
# создаем список и наполняем его данными
with open(filename) as f:
    pop_data = json.load(f)
# выводим население за 2010 год
for pop_dict in pop_data:
    if pop_dict['Year'] == '2010':
        country_name = pop_dict['Country Name']
        population = pop_dict['Value']
        print(country_name + ": " + population)
# Out:
# Arab World: 357868000
# Caribbean small states: 6880000
# East Asia & Pacific (all income levels): 2201536674
# East Asia & Pacific (developing only): 1961558757
# Euro area: 331766000
# Europe & Central Asia (all income levels): 890424544
# Europe & Central Asia (developing only): 405204000
# European Union: 502125000
# Heavily indebted poor countries (HIPC): 635663000
# High income: 1127437398.85751
# High income: nonOECD: 94204398.857512
# High income: OECD: 1033233000
# Latin America & Caribbean (all income levels): 589011025.857512
# Latin America & Caribbean (developing only): 582551688
# Least developed countries: UN classification: 835140827
# Low & middle income: 5767157445
# Low income: 796342000
# Lower middle income: 2518690865
# Middle East & North Africa (all income levels): 382803000
# Middle East & North Africa (developing only): 331263000
# Middle income: 4970815445
# North America: 343539600
# OECD members: 1236521688
# Other small states: 18293000
# ...

# %%
#так выглядит наш список словарей (json)
pop_data[:5]
# Out:
# [{'Country Name': 'Arab World',
#   'Country Code': 'ARB',
#   'Year': '1960',
#   'Value': '96388069'},
#  {'Country Name': 'Arab World',
#   'Country Code': 'ARB',
#   'Year': '1961',
#   'Value': '98882541.4'},
#  {'Country Name': 'Arab World',
#   'Country Code': 'ARB',
#   'Year': '1962',
#   'Value': '101474075.8'},
#  {'Country Name': 'Arab World',
#   'Country Code': 'ARB',
#   'Year': '1963',
#   'Value': '104169209.2'},
#  {'Country Name': 'Arab World',
#   'Country Code': 'ARB',
#   'Year': '1964',
#   'Value': '106978104.6'}]

# %%
filename = 'population_data.json'
# создаем список и наполняем его данными
with open(filename) as f:
    pop_data = json.load(f)
# выводим население за 2010 год
for pop_dict in pop_data:
    if pop_dict['Year'] == '2010':
        country_name = pop_dict['Country Name']
        population = int(float(pop_dict['Value'])) # преобразуем в float, затем в int, отсекая дробную часть
        print(country_name + ": " + str(population))
# Out:
# Arab World: 357868000
# Caribbean small states: 6880000
# East Asia & Pacific (all income levels): 2201536674
# East Asia & Pacific (developing only): 1961558757
# Euro area: 331766000
# Europe & Central Asia (all income levels): 890424544
# Europe & Central Asia (developing only): 405204000
# European Union: 502125000
# Heavily indebted poor countries (HIPC): 635663000
# High income: 1127437398
# High income: nonOECD: 94204398
# High income: OECD: 1033233000
# Latin America & Caribbean (all income levels): 589011025
# Latin America & Caribbean (developing only): 582551688
# Least developed countries: UN classification: 835140827
# Low & middle income: 5767157445
# Low income: 796342000
# Lower middle income: 2518690865
# Middle East & North Africa (all income levels): 382803000
# Middle East & North Africa (developing only): 331263000
# Middle income: 4970815445
# North America: 343539600
# OECD members: 1236521688
# Other small states: 18293000
# ...

# %%
#нужно смапить трехбуквенные коды стран с названиями стран
#from pygal.i18n import COUNTRIES
from pygal import COUNTRIES
for country_code in sorted(COUNTRIES.keys()):
    print(country_code, COUNTRIES[country_code])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-518-bfcf408357af> in <module>()
#       1 #нужно смапить трехбуквенные коды стран с названиями стран
#       2 #from pygal.i18n import COUNTRIES
# ----> 3 from pygal import COUNTRIES
#       4 for country_code in sorted(COUNTRIES.keys()):
#       5     print(country_code, COUNTRIES[country_code])
#
# ImportError: cannot import name 'COUNTRIES' from 'pygal' (C:\Users\User\AppData\Roaming\Python\Python37\site-packages\pygal\__init__.py)

# %% [markdown]
# Модуль i18n был удален в pygal-2.0.0, однако теперь его можно найти в плагине pygal_maps_world.
#
# Вы можете установить это с помощью pip install pygal_maps_world. Затем вы можете получить доступ к COUNTRIES как pygal.maps.world.COUNTRIES:
#
# from pygal.maps.world import COUNTRIES
# Остальные из модуля i18n можно импортировать с помощью:
#
# from pygal_maps_world import i18n

# %%
!  pip install pygal_maps_world

# %%
from pygal.maps import COUNTRIES
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-520-e4b89bf5eeb1> in <module>()
# ----> 1 from pygal.maps import COUNTRIES
#
# ImportError: cannot import name 'COUNTRIES' from 'pygal.maps' (C:\Users\User\AppData\Roaming\Python\Python37\site-packages\pygal\maps\__init__.py)

# %%
#советы с сайта http://qaru.site/questions/717121/cant-import-countries-from-pygali18n не помогли
#В архиве  Downloading https://files.pythonhosted.org/packages/a0/6e/2471c9db8e5402f844cdab2e6270fb315ee83e308d4977e356a04ca76c36/pygal_maps_world-1.0.2.tar.gz (270kB)
#нашелся файл i18n
# скопировал его в C:\Users\User\AppData\Roaming\Python\Python37\site-packages\pygal

# %%
from pygal.i18n import COUNTRIES

# %%
for country_code in sorted(COUNTRIES.keys()):
    print(country_code, COUNTRIES[country_code])
# Out:
# ad Andorra
# ae United Arab Emirates
# af Afghanistan
# al Albania
# am Armenia
# ao Angola
# aq Antarctica
# ar Argentina
# at Austria
# au Australia
# az Azerbaijan
# ba Bosnia and Herzegovina
# bd Bangladesh
# be Belgium
# bf Burkina Faso
# bg Bulgaria
# bh Bahrain
# bi Burundi
# bj Benin
# bn Brunei Darussalam
# bo Bolivia, Plurinational State of
# br Brazil
# bt Bhutan
# bw Botswana
# by Belarus
# bz Belize
# ca Canada
# cd Congo, the Democratic Republic of the
# cf Central African Republic
# cg Congo
# ch Switzerland
# ci Cote d'Ivoire
# cl Chile
# cm Cameroon
# cn China
# co Colombia
# cr Costa Rica
# cu Cuba
# cv Cape Verde
# cy Cyprus
# cz Czech Republic
# de Germany
# dj Djibouti
# dk Denmark
# do Dominican Republic
# dz Algeria
# ec Ecuador
# ee Estonia
# eg Egypt
# eh Western Sahara
# er Eritrea
# es Spain
# et Ethiopia
# fi Finland
# fr France
# ga Gabon
# gb United Kingdom
# ge Georgia
# gf French Guiana
# gh Ghana
# gl Greenland
# gm Gambia
# gn Guinea
# ...

# %%
from pygal.i18n import COUNTRIES
def get_country_code(country_name):
    """возвращает для заданной страны ее 2 буквенный код pygal"""
    for code, name in COUNTRIES.items():
        if name == country_name:
            return code
    #если страна не найдена - вернуть None
    return None

# %%
print(get_country_code('Belarus'))
print(get_country_code('Russian Federation'))
print(get_country_code('Andorra'))
# Out:
# by
# ru
# ad

# %%
filename = 'population_data.json'
# создаем список и наполняем его данными
with open(filename) as f:
	pop_data = json.load(f)
# выводим население за 2010 год
for pop_dict in pop_data:
	if pop_dict['Year'] == '2010':
		country_name = pop_dict['Country Name']
		population = int(float(pop_dict['Value'])) # преобразуем в float, затем в int, отсекая дробную часть
		code = get_country_code(country_name) # вместо названия получаем код
		if code:
			print(code + ": " + str(population))
		else:
			print('ERROR - ' + country_name)
# Out:
# ERROR - Arab World
# ERROR - Caribbean small states
# ERROR - East Asia & Pacific (all income levels)
# ERROR - East Asia & Pacific (developing only)
# ERROR - Euro area
# ERROR - Europe & Central Asia (all income levels)
# ERROR - Europe & Central Asia (developing only)
# ERROR - European Union
# ERROR - Heavily indebted poor countries (HIPC)
# ERROR - High income
# ERROR - High income: nonOECD
# ERROR - High income: OECD
# ERROR - Latin America & Caribbean (all income levels)
# ERROR - Latin America & Caribbean (developing only)
# ERROR - Least developed countries: UN classification
# ERROR - Low & middle income
# ERROR - Low income
# ERROR - Lower middle income
# ERROR - Middle East & North Africa (all income levels)
# ERROR - Middle East & North Africa (developing only)
# ERROR - Middle income
# ERROR - North America
# ERROR - OECD members
# ERROR - Other small states
# ERROR - Pacific island small states
# ERROR - Small states
# ERROR - South Asia
# ...

# %%
#пока не берем для анализа данные стран, по котороым получена ошибка

# %%
#import pygal
wm = pygal.Worldmap()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-528-94c2d9e8a1c1> in <module>()
#       1 #import pygal
# ----> 2 wm = pygal.Worldmap()
#
# AttributeError: module 'pygal' has no attribute 'Worldmap'

# %%
! pip install pygal_maps_world

# %%
worldmap_chart = pygal.maps.world.World()
worldmap_chart.title = 'Some countries'
worldmap_chart.add('F countries', ['fr', 'fi'])
worldmap_chart.add('M countries', ['ma', 'mc', 'md', 'me', 'mg',
                                   'mk', 'ml', 'mm', 'mn', 'mo',
                                   'mr', 'mt', 'mu', 'mv', 'mw',
                                   'mx', 'my', 'mz'])
worldmap_chart.add('U countries', ['ua', 'ug', 'us', 'uy', 'uz'])
worldmap_chart.render()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-530-ab2def031628> in <module>()
# ----> 1 worldmap_chart = pygal.maps.world.World()
#       2 worldmap_chart.title = 'Some countries'
#       3 worldmap_chart.add('F countries', ['fr', 'fi'])
#       4 worldmap_chart.add('M countries', ['ma', 'mc', 'md', 'me', 'mg',
#       5                                    'mk', 'ml', 'mm', 'mn', 'mo',
#
# AttributeError: module 'pygal.maps' has no attribute 'world'

# %%
pygal.maps
# Out:
# <module 'pygal.maps' from 'C:\\Users\\User\\AppData\\Roaming\\Python\\Python37\\site-packages\\pygal\\maps\\__init__.py'>

# %%
# c pygal проблемы какие-то

# %%
from bokeh.plotting import figure, show, output_file
from bokeh.tile_providers import CARTODBPOSITRON

output_file("tile.html")

# range bounds supplied in web mercator coordinates
p = figure(x_range=(-2000000, 6000000), y_range=(-1000000, 7000000),
           x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(CARTODBPOSITRON)

show(p)

# %%
! pip install vincent

# %%
#попробуем использовать винсент
import vincent
vincent.core.initialize_notebook()
world_topo="static/custom/world-countries.topo.json"
geo_data = [{'name': 'countries',
         'url': world_topo,
         'feature': 'world-countries'}]
vis = vincent.Map(geo_data=geo_data, scale=100)
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
# ...

# %%
vis.display()
# Out:
# <div id="vis5fcb4dadfd6946758650a4bed0860c07"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"format": {"feature": "world-countries", "type": "topojson"}, "name": "countries", "transform": [{"projection": "winkel3", "scale": 200, "translate": [480.0, 250.0], "type": "geopath", "value": "data"}], "url": "https://raw.githubusercontent.com/wrobstory/vincent_map_data/master/world-countries.topo.json"}], "height": 500, "legends": [], "marks": [{"from": {"data": "countries"}, "properties": {"enter": {"path": {"field": "path"}, "stroke": {"value": "#000000"}}, "update": {"fill": {"value": "#084010"}}}, "type": "path"}], "padding": "auto", "scales": [], "width": 960}, function(chart) {
#          chart({el: "#vis5fcb4dadfd6946758650a4bed0860c07"}).update();
#        });
#      };
# ...

# %%
import pandas

world_topo="https://raw.githubusercontent.com/wrobstory/vincent_map_data/master/world-countries.topo.json"
geo_data = [{'name': 'countries',
            'url': world_topo,
            'feature': 'world-countries'}]

vis = vincent.Map(geo_data=geo_data, scale=200)
vis.to_json('vega.json')
vis.marks[0].properties.update.fill.value = '#084010'
vis.display()
# Out:
# <div id="vis0e2c98f92dcf4dbbaf9a8988aa595b13"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"format": {"feature": "world-countries", "type": "topojson"}, "name": "countries", "transform": [{"projection": "winkel3", "scale": 200, "translate": [480.0, 250.0], "type": "geopath", "value": "data"}], "url": "https://raw.githubusercontent.com/wrobstory/vincent_map_data/master/world-countries.topo.json"}], "height": 500, "legends": [], "marks": [{"from": {"data": "countries"}, "properties": {"enter": {"path": {"field": "path"}, "stroke": {"value": "#000000"}}, "update": {"fill": {"value": "#084010"}}}, "type": "path"}], "padding": "auto", "scales": [], "width": 960}, function(chart) {
#          chart({el: "#vis0e2c98f92dcf4dbbaf9a8988aa595b13"}).update();
#        });
#      };
# ...

# %%
# vincent не понравился
# в галерее плотли неплохой шаблон, жаль что отрисовывает только США
import plotly.plotly as py
import pandas as pd
from plotly.offline import init_notebook_mode, iplot
import plotly
import plotly.graph_objs as go

init_notebook_mode(connected=True)

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')

for col in df.columns:
    df[col] = df[col].astype(str)

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

df['text'] = df['state'] + '<br>' +\
    'Beef '+df['beef']+' Dairy '+df['dairy']+'<br>'+\
    'Fruits '+df['total fruits']+' Veggies ' + df['total veggies']+'<br>'+\
    'Wheat '+df['wheat']+' Corn '+df['corn']

data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = df['code'],
        z = df['total exports'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Millions USD")
        ) ]

layout = dict(
        title = '2011 US Agriculture Exports by State<br>(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
iplot( fig, show_link=False )
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# ...

# %%
import plotly.plotly as py
import pandas as pd
from plotly.offline import init_notebook_mode, iplot
import plotly
import plotly.graph_objs as go
init_notebook_mode(connected=True)

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_world_gdp_with_codes.csv')

data = [ dict(
        type = 'choropleth',
        locations = df['CODE'],
        z = df['GDP (BILLIONS)'],
        text = df['COUNTRY'],
        colorscale = [[0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
            [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]],
        autocolorscale = False,
        reversescale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            tickprefix = '$',
            title = 'GDP<br>Billions US$'),
      ) ]

layout = dict(
    title = '2014 Global GDP<br>Source:\
            <a href="https://www.cia.gov/library/publications/the-world-factbook/fields/2195.html">\
            CIA World Factbook</a>',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)



fig = dict( data=data, layout=layout )
iplot( fig, show_link=False , validate=False)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# ...

# %%
# возьмем это за основу

# %%
world_gdp_with_codes_df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_world_gdp_with_codes.csv')
world_gdp_with_codes_df.head(5)
# Out:
#           COUNTRY  GDP (BILLIONS) CODE
# 0     Afghanistan           21.71  AFG
# 1         Albania           13.40  ALB
# 2         Algeria          227.80  DZA
# 3  American Samoa            0.75  ASM
# 4         Andorra            4.80  AND

# %%
#Создадим список кодов
country_codes_3 = []
for row in world_gdp_with_codes_df.CODE:
    country_codes_3.append(row)
    #print(row)
country_codes_3[:10]
# Out:
# ['AFG', 'ALB', 'DZA', 'ASM', 'AND', 'AGO', 'AIA', 'ATG', 'ARG', 'ARM']

# %%
#перепишем функцию get_country_code
def get_country_code(country_name):
    """возвращает для заданной страны ее 3 буквенный код"""
    for code in country_codes_3:
        if code in pop_data:
            return code
    #если страна не найдена - вернуть None
    return None

# %%
pop_data[0]['Country Code']
# Out:
# 'ARB'

# %%
filename = 'population_data.json'
# создаем список и наполняем его данными
with open(filename) as f:
    pop_data = json.load(f)
# выводим население за 2010 год
for pop_dict in pop_data:
    if pop_dict['Year'] == '2010':
        country_name = pop_dict['Country Name']
        population = int(float(pop_dict['Value'])) # преобразуем в float, затем в int, отсекая дробную часть
        code = pop_dict['Country Code']
        print(code + ": " + str(population))
# Out:
# ARB: 357868000
# CSS: 6880000
# EAS: 2201536674
# EAP: 1961558757
# EMU: 331766000
# ECS: 890424544
# ECA: 405204000
# EUU: 502125000
# HPC: 635663000
# HIC: 1127437398
# NOC: 94204398
# OEC: 1033233000
# LCN: 589011025
# LAC: 582551688
# LDC: 835140827
# LMY: 5767157445
# LIC: 796342000
# LMC: 2518690865
# MEA: 382803000
# MNA: 331263000
# MIC: 4970815445
# NAC: 343539600
# OED: 1236521688
# OSS: 18293000
# PSS: 3345337
# SST: 28518337
# SAS: 1633146000
# SSF: 854134000
# SSA: 853434000
# UMC: 2452124580
# WLD: 6894594843
# AFG: 34385000
# ALB: 3205000
# DZA: 35468000
# ASM: 68420
# AND: 84864
# AGO: 19082000
# ATG: 88000
# ARG: 40412000
# ARM: 3092000
# ABW: 108000
# AUS: 22299000
# AUT: 8390000
# AZE: 9054000
# BHS: 343000
# BHR: 1262000
# BGD: 148692000
# BRB: 274000
# BLR: 9490000
# BEL: 10896000
# BLZ: 345000
# BEN: 8850000
# BMU: 64600
# BTN: 726000
# BOL: 9929000
# BIH: 3760000
# BWA: 2007000
# BRA: 194946000
# BRN: 399000
# BGR: 7534000
# BFA: 16468000
# BDI: 8382000
# ...

# %%
filename = 'population_data.json'
# создаем список и наполняем его данными
with open(filename) as f:
    pop_data = json.load(f)
# выводим население за 2010 год
locations = []
z = []
for pop_dict in pop_data:
    if pop_dict['Year'] == '2010':
        country_name = pop_dict['Country Name']
        population = int(float(pop_dict['Value'])) # преобразуем в float, затем в int, отсекая дробную часть
        z.append(population)
        code = pop_dict['Country Code']
        locations.append(code)
        print(code + ": " + str(population))
# Out:
# ARB: 357868000
# CSS: 6880000
# EAS: 2201536674
# EAP: 1961558757
# EMU: 331766000
# ECS: 890424544
# ECA: 405204000
# EUU: 502125000
# HPC: 635663000
# HIC: 1127437398
# NOC: 94204398
# OEC: 1033233000
# LCN: 589011025
# LAC: 582551688
# LDC: 835140827
# LMY: 5767157445
# LIC: 796342000
# LMC: 2518690865
# MEA: 382803000
# MNA: 331263000
# MIC: 4970815445
# NAC: 343539600
# OED: 1236521688
# OSS: 18293000
# PSS: 3345337
# SST: 28518337
# SAS: 1633146000
# SSF: 854134000
# SSA: 853434000
# UMC: 2452124580
# WLD: 6894594843
# AFG: 34385000
# ALB: 3205000
# DZA: 35468000
# ASM: 68420
# AND: 84864
# AGO: 19082000
# ATG: 88000
# ARG: 40412000
# ARM: 3092000
# ABW: 108000
# AUS: 22299000
# AUT: 8390000
# AZE: 9054000
# BHS: 343000
# BHR: 1262000
# BGD: 148692000
# BRB: 274000
# BLR: 9490000
# BEL: 10896000
# BLZ: 345000
# BEN: 8850000
# BMU: 64600
# BTN: 726000
# BOL: 9929000
# BIH: 3760000
# BWA: 2007000
# BRA: 194946000
# BRN: 399000
# BGR: 7534000
# BFA: 16468000
# BDI: 8382000
# ...

# %%
import plotly.plotly as py
import pandas as pd
from plotly.offline import init_notebook_mode, iplot
import plotly
import plotly.graph_objs as go
init_notebook_mode(connected=True)

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_world_gdp_with_codes.csv')

data = [ dict(
        type = 'choropleth',
        locations = locations,
        z = z,
        #text = df['COUNTRY'],
        colorscale = [[0,"rgb(5, 10, 100)"],[0.5,"rgb(70, 100, 200)"],[0.7,"rgb(90, 120, 300)"],\
            [0.8,"rgb(110, 140, 400)"],[0.9,"rgb(130, 160, 500)"],[1,"rgb(220, 220, 600)"]],
        autocolorscale = False,
        reversescale = True,
        marker = dict(
            line = dict (
                #color = 'rgb(180,180,180)',
                color = '#333333',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            color = 'red',
            tickprefix = '',
            title = 'Население<br>человек'),
      ) ]

layout = dict(
    title = 'Численность населения мира<br>Источник:\
            <a href="http://data.okfn.org">\
            Open Knowledge Foundation</a>',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)



fig = dict( data=data, layout=layout )
#plotly.offline.plot( fig, filename='123.html', show_link=False , validate=False) #если надо сохранить html
iplot(fig, filename='123.html', show_link=False, validate=False);
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# ...

# %%
filename = 'population_data.json'
# создаем список и наполняем его данными
with open(filename) as f:
	pop_data = json.load(f)
# выводим население за 2010 год
for pop_dict in pop_data:
	if pop_dict['Year'] == '2010':
		country_name = pop_dict['Country Name']
		population = int(float(pop_dict['Value'])) # преобразуем в float, затем в int, отсекая дробную часть
		code = get_country_code(country_name) # вместо названия получаем код
		if code:
			print(code + ": " + str(population))
		else:
			print('ERROR - ' + country_name)
# Out:
# ERROR - Arab World
# ERROR - Caribbean small states
# ERROR - East Asia & Pacific (all income levels)
# ERROR - East Asia & Pacific (developing only)
# ERROR - Euro area
# ERROR - Europe & Central Asia (all income levels)
# ERROR - Europe & Central Asia (developing only)
# ERROR - European Union
# ERROR - Heavily indebted poor countries (HIPC)
# ERROR - High income
# ERROR - High income: nonOECD
# ERROR - High income: OECD
# ERROR - Latin America & Caribbean (all income levels)
# ERROR - Latin America & Caribbean (developing only)
# ERROR - Least developed countries: UN classification
# ERROR - Low & middle income
# ERROR - Low income
# ERROR - Lower middle income
# ERROR - Middle East & North Africa (all income levels)
# ERROR - Middle East & North Africa (developing only)
# ERROR - Middle income
# ERROR - North America
# ERROR - OECD members
# ERROR - Other small states
# ERROR - Pacific island small states
# ERROR - Small states
# ERROR - South Asia
# ...

# %%
#код ужасный, но таково было задание в книге
from pygal.i18n import COUNTRIES
def get_country_code(country_name):
    """возвращает для заданной страны ее 3 буквенный код"""
    for code, name in COUNTRIES.items():
        if name == country_name:
            return code
        elif name == 'American Samoa':
            return 'ASM'
        elif name == 'Antigua and Barbuda':
            return 'ATG'
        elif name == 'Aruba':
            return 'ABW'
        elif name == 'Bahamas':
            return 'BHM'
        elif name ==    'Barbados':
            return 'BRB'
        elif name ==    'Bermuda':
            return 'BMU'
        elif name ==    'Bolivia':
            return 'BOL'
        elif name ==    'Cayman Islands':
            return 'CYM'
        
        elif name ==    'Comoros':
            return 'COM'
        elif name ==    'Congo, Rep.':
            return 'COG'
        elif name == 'Congo, Dem. Rep.':
            return 'COD'
        elif name ==    'Curacao':
            return 'CUW'
        elif name ==    'Dominica':
            return 'DMA'
        elif name ==    'Egypt, Arab Rep.':
            return 'EGY'
        elif name ==    'Faeroe Islands':
            return 'FRO'
        elif name ==    'Fiji':
            return 'FJI'
        elif name ==    'French Polynesia':
            return 'PYF'
        elif name ==    'Gambia, The':
            return 'GMB'
        elif name ==   'Gibraltar':
            return 'GIB'
        elif name ==  'Grenada':
            return 'GRD'
        elif name ==    'Hong Kong SAR, China':
            return 'HKG'
        elif name ==    'Iran, Islamic Rep.':
            return 'IRN'
        elif name ==     'Isle of Man':
            return 'IMN'
        elif name ==     'Kiribati':
            return 'KIR'
        elif name ==      'Korea, Dem. Rep.':
            return 'KOR'
        elif name ==      'Korea, Rep.':
            return 'PRK'
        elif name ==      'Kosovo':
            return 'KSV'
        elif name ==      'Kyrgyz Republic':
            return 'KGZ'
        elif name ==     'Lao PDR':
            return 'LAO'
        elif name ==  'Libya':
            return 'LBY'
        elif name == 'Macao SAR, China':
            return 'MAC'
        elif name == 'Macedonia, FYR':
            return 'MKD'
        elif name == 'Marshall Islands':
            return 'MHL'
        elif name == 'Micronesia, Fed. Sts.':
            return 'FSM'
        elif name == 'Moldova':
            return 'MDA'
        elif name == 'New Caledonia':
            return 'NCL'
        elif name == 'Northern Mariana Islands':
            return 'MNP'
        elif name == 'Palau':
            return 'PLW'
        elif name == 'Qatar':
            return 'QAT'
        elif name ==  'Samoa':
            return 'WSM'
        elif name == 'Sint Maarten (Dutch part)':
            return 'SXM'
        elif name == 'Slovak Republic':
            return 'SVK'
        elif name == 'Solomon Islands':
            return 'SLB'
        elif name ==  'St. Kitts and Nevis':
            return 'KNA'
        elif name ==   'St. Lucia':
            return 'LCA'
        elif name ==  'St. Martin (French part)':
            return 'MAF'
        elif name ==  'St. Vincent and the Grenadines':
            return 'VCT'
        elif name ==  'Tanzania':
            return 'TZA'
        elif name ==  'Tonga':
            return 'TON'
        elif name == 'Trinidad and Tobago':
            return 'TTO'
        
        elif name == 'Tuvalu':
            return 'TUV'
        elif name == 'Vanuatu':
            return 'VUT'
        elif name == 'Venezuela, RB':
            return 'VEN'
        elif name ==  'Vietnam':
            return 'VNM'
        elif name == 'Virgin Islands (U.S.)':
            return 'VGB'
        elif name ==  'West Bank and Gaza':
            return 'WBG'
        elif name ==  'Yemen, Rep.':
            return 'YEM'


    #если страна не найдена - вернуть None
    return None

# %%
filename = 'population_data.json'
# создаем список и наполняем его данными
with open(filename) as f:
    pop_data = json.load(f)
# выводим население за 2010 год
locations = []
z = []
for pop_dict in pop_data:
    if pop_dict['Year'] == '2010':
        country_name = pop_dict['Country Name']
        population = int(float(pop_dict['Value'])) # преобразуем в float, затем в int, отсекая дробную часть
        z.append(population)
        code = pop_dict['Country Code']
        locations.append(code)
        print(code + ": " + str(population))
# Out:
# ARB: 357868000
# CSS: 6880000
# EAS: 2201536674
# EAP: 1961558757
# EMU: 331766000
# ECS: 890424544
# ECA: 405204000
# EUU: 502125000
# HPC: 635663000
# HIC: 1127437398
# NOC: 94204398
# OEC: 1033233000
# LCN: 589011025
# LAC: 582551688
# LDC: 835140827
# LMY: 5767157445
# LIC: 796342000
# LMC: 2518690865
# MEA: 382803000
# MNA: 331263000
# MIC: 4970815445
# NAC: 343539600
# OED: 1236521688
# OSS: 18293000
# PSS: 3345337
# SST: 28518337
# SAS: 1633146000
# SSF: 854134000
# SSA: 853434000
# UMC: 2452124580
# WLD: 6894594843
# AFG: 34385000
# ALB: 3205000
# DZA: 35468000
# ASM: 68420
# AND: 84864
# AGO: 19082000
# ATG: 88000
# ARG: 40412000
# ARM: 3092000
# ABW: 108000
# AUS: 22299000
# AUT: 8390000
# AZE: 9054000
# BHS: 343000
# BHR: 1262000
# BGD: 148692000
# BRB: 274000
# BLR: 9490000
# BEL: 10896000
# BLZ: 345000
# BEN: 8850000
# BMU: 64600
# BTN: 726000
# BOL: 9929000
# BIH: 3760000
# BWA: 2007000
# BRA: 194946000
# BRN: 399000
# BGR: 7534000
# BFA: 16468000
# BDI: 8382000
# ...

# %%
#построим уже визуализацию численности населения
import plotly.plotly as py
import pandas as pd
from plotly.offline import init_notebook_mode, iplot
import plotly
import plotly.graph_objs as go
init_notebook_mode(connected=True)

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_world_gdp_with_codes.csv')

data = [ dict(
        type = 'choropleth',
        locations = locations,
        z = z,
        #text = df['COUNTRY'],
        colorscale = [[0,"rgb(5, 10, 100)"],[0.5,"rgb(70, 100, 200)"],[0.7,"rgb(90, 120, 300)"],\
            [0.8,"rgb(110, 140, 400)"],[0.9,"rgb(130, 160, 500)"],[1,"rgb(220, 220, 600)"]],
        autocolorscale = False,
        reversescale = True,
        marker = dict(
            line = dict (
                #color = 'rgb(180,180,180)',
                color = '#333333',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            color = 'red',
            tickprefix = '',
            title = 'Население<br>человек'),
      ) ]

layout = dict(
    title = 'Численность населения мира<br>Источник:\
            <a href="http://data.okfn.org">\
            Open Knowledge Foundation</a>',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)



fig = dict( data=data, layout=layout )
#plotly.offline.plot( fig, filename='123.html', show_link=False , validate=False) #если надо сохранить html
iplot(fig, filename='1234.html', show_link=False, validate=False);
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# ...

# %%
# визуализируем данные по ВВП gdp_csv.csv с сайта всемирного банка

# %%
import pandas as pd
world_gdp_df = pd.read_csv('gdp_csv.csv')
world_gdp_df.head(5)
#посмотрим на данные
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
# какой год самый последний?
world_gdp_df.sort_values('Year', ascending=False).head(10)
# Out:
#                     Country Name Country Code  Year         Value
# 11506                   Zimbabwe          ZWE  2016  1.661996e+10
# 5111                        Fiji          FJI  2016  4.703633e+09
# 1802   Post-demographic dividend          PST  2016  4.521331e+13
# 7630                       Malta          MLT  2016  1.099905e+10
# 2495                     Andorra          AND  2016  2.858518e+09
# 2986                    Barbados          BRB  2016  4.529050e+09
# 3469                      Brazil          BRA  2016  1.796187e+12
# 1859    Pre-demographic dividend          PRE  2016  1.207788e+12
# 7583                        Mali          MLI  2016  1.403498e+10
# 6180                   Indonesia          IDN  2016  9.322592e+11

# %%
world_gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11507 entries, 0 to 11506
# Data columns (total 4 columns):
# Country Name    11507 non-null object
# Country Code    11507 non-null object
# Year            11507 non-null int64
# Value           11507 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 359.7+ KB

# %%
#посмотрим на json
with open(filename) as f:
    gdp_data = json.load(f)
gdp_data[:5]
# Out:
# [{'Country Name': 'Arab World',
#   'Country Code': 'ARB',
#   'Year': '1960',
#   'Value': '96388069'},
#  {'Country Name': 'Arab World',
#   'Country Code': 'ARB',
#   'Year': '1961',
#   'Value': '98882541.4'},
#  {'Country Name': 'Arab World',
#   'Country Code': 'ARB',
#   'Year': '1962',
#   'Value': '101474075.8'},
#  {'Country Name': 'Arab World',
#   'Country Code': 'ARB',
#   'Year': '1963',
#   'Value': '104169209.2'},
#  {'Country Name': 'Arab World',
#   'Country Code': 'ARB',
#   'Year': '1964',
#   'Value': '106978104.6'}]

# %%
filename = 'gdp_j.json'

with open(filename) as f:
    gdp_data = json.load(f)
gdps = []
locations = []
for gdp_dict in gdp_data:
    if gdp_dict['Year'] == 2016:
        gdp = gdp_dict['Value']
        gdps.append(gdp)
        
print(gdps[:10]) #посмотрим первые 10 значений одного из получившихся словарей
# Out:
# [2504702625568.63, 66707362091.378, 1312157690492.89, 10401989026722.8, 22480427869996.2, 13512435638588.8, 13486492444155.4, 11934055071906.0, 20273841359271.0, 2991823901020.52]

# %%
#Выведем данные в формате код страны - значение
filename = 'gdp_j.json'
with open(filename) as f:
    gdp_data = json.load(f)
gdps = []
locations = []
for gdp_dict in gdp_data:
    if str(gdp_dict['Year']) == '2016':
        gdp = int(gdp_dict['Value'])
        gdps.append(gdp)
        code = gdp_dict['Country Code']
        locations.append(code)
        print(code + ": " + str(gdp))
# Out:
# ARB: 2504702625568
# CSS: 66707362091
# CEB: 1312157690492
# EAR: 10401989026722
# EAS: 22480427869996
# EAP: 13512435638588
# TEA: 13486492444155
# EMU: 11934055071906
# ECS: 20273841359271
# ECA: 2991823901020
# TEC: 3463188309734
# EUU: 16487344364513
# FCS: 744250583417
# HPC: 648289348137
# HIC: 48557463061833
# IBD: 25981476556760
# IBT: 27972819139754
# IDB: 923606013413
# IDX: 1072786488210
# IDA: 1999807711387
# LTE: 18455074977717
# LCN: 5299865625774
# LAC: 4853042525000
# TLA: 5094164385266
# LDC: 940734369537
# LMY: 27299380819539
# LIC: 402524119028
# LMC: 6263372909106
# MEA: 3144797691272
# MNA: 1453901029336
# TMN: 1440244500023
# MIC: 26897069180752
# NAC: 20160296406469
# OED: 47552622005124
# OSS: 362079512486
# PSS: 9019651488
# PST: 45213309475250
# PRE: 1207787697187
# SST: 437803722143
# SAS: 2892480763179
# TSA: 2892480763179
# SSF: 1512596044161
# SSA: 1511168024853
# TSS: 1512596044161
# UMC: 20623856301266
# WLD: 75845109381590
# AFG: 19469022207
# ...

# %%
# визуализация данных по ВВП 2014 год
import plotly.plotly as py
import pandas as pd
from plotly.offline import init_notebook_mode, iplot
import plotly
import plotly.graph_objs as go
init_notebook_mode(connected=True)

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_world_gdp_with_codes.csv')

data = [ dict(
        type = 'choropleth',
        locations = locations,
        z = gdps,
        #text = df['COUNTRY'],
        colorscale = [[0,"rgb(5, 10, 100)"],[0.5,"rgb(70, 100, 200)"],[0.7,"rgb(90, 120, 300)"],\
            [0.8,"rgb(110, 140, 400)"],[0.9,"rgb(130, 160, 500)"],[1,"rgb(220, 220, 600)"]],
        autocolorscale = False,
        reversescale = True,
        marker = dict(
            line = dict (
                #color = 'rgb(180,180,180)',
                color = '#333333',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            #tickprefix = '$',
            color = 'red',
            tickprefix = '',
            title = 'ВВП<br>$'),
      ) ]

layout = dict(
    title = 'ВВП стран мира<br>Источник:\
            <a href="http://data.okfn.org">\
            Open Knowledge Foundation</a>',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)



fig = dict( data=data, layout=layout )
#plotly.offline.plot( fig, filename='1234.html', show_link=False , validate=False) #если надо сохранить html
iplot(fig, filename='1234.html', show_link=False, validate=False);
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# ...

# %%
# посмотрим еще один датасет Human Capital Index за 2017 год из https://datacatalog.worldbank.org/dataset/human-capital-index

# %%
#import pandas as pd
hci_df = pd.read_csv('HCIData.csv')
hci_df.head(54)
#посмотрим на данные
# Out:
#    Country Name Country Code  \
# 0   Afghanistan          AFG
# 1   Afghanistan          AFG
# 2   Afghanistan          AFG
# 3   Afghanistan          AFG
# 4   Afghanistan          AFG
# 5   Afghanistan          AFG
# 6   Afghanistan          AFG
# 7   Afghanistan          AFG
# 8   Afghanistan          AFG
# 9   Afghanistan          AFG
# 10  Afghanistan          AFG
# 11  Afghanistan          AFG
# 12  Afghanistan          AFG
# 13  Afghanistan          AFG
# 14  Afghanistan          AFG
# 15  Afghanistan          AFG
# 16  Afghanistan          AFG
# 17  Afghanistan          AFG
# 18  Afghanistan          AFG
# 19  Afghanistan          AFG
# 20  Afghanistan          AFG
# 21  Afghanistan          AFG
# 22  Afghanistan          AFG
# 23  Afghanistan          AFG
# 24  Afghanistan          AFG
# 25  Afghanistan          AFG
# 26  Afghanistan          AFG
# 27      Albania          ALB
# 28      Albania          ALB
# 29      Albania          ALB
# 30      Albania          ALB
# ...

# %%
#список столбцов
import csv # модуль для чтения csv
filename = 'HCIData.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    print(header_row)
# Out:
# ['п»ї"Country Name"', 'Country Code', 'Indicator Name', 'Indicator Code', '2017', '']

# %%
# Пронумеруем столбцы. Значения - столбец 4
filename = 'HCIData.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    for index, column_header in enumerate(header_row):
        print(index, column_header)
# Out:
# 0 п»ї"Country Name"
# 1 Country Code
# 2 Indicator Name
# 3 Indicator Code
# 4 2017
# 5

# %%
#проверим типы данных
hci_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4239 entries, 0 to 4238
# Data columns (total 6 columns):
# Country Name      4239 non-null object
# Country Code      4239 non-null object
# Indicator Name    4239 non-null object
# Indicator Code    4239 non-null object
# 2017              3709 non-null float64
# Unnamed: 5        0 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 198.8+ KB

# %%
# статистика: строк и столбцов
hci_df.shape
# Out:
# (4239, 6)

# %%
# дропнем неполные строки и проверим еще раз
hci_df.dropna()
hci_df.shape
# Out:
# (4239, 6)

# %%
#пустых строк нет, типы данныхменять не нужно.

# %%
#выберем полезные столбцы
col = ['Country Code', 'Indicator Code', '2017']

hci_df[col].head()
# Out:
#   Country Code  Indicator Code   2017
# 0          AFG     HD.HCI.EYRS  8.580
# 1          AFG  HD.HCI.EYRS.FE  6.730
# 2          AFG  HD.HCI.EYRS.MA  9.210
# 3          AFG     HD.HCI.STNT  0.591
# 4          AFG  HD.HCI.STNT.FE    NaN

# %%
#названия у колонок нужно поменять
# было: ['п»ї"Country Name"', 'Country Code', 'Indicator Name', 'Indicator Code', '2017', '']. Стало:
hci_df.columns = ['country_name','country_code', 'indicator_name', 'indicator_code', 'value', 'other']
hci_df.head()
# Out:
#   country_name country_code                                    indicator_name  \
# 0  Afghanistan          AFG                          Expected Years of School
# 1  Afghanistan          AFG                  Expected Years of School, Female
# 2  Afghanistan          AFG                    Expected Years of School, Male
# 3  Afghanistan          AFG          Fraction of Children Under 5 Not Stunted
# 4  Afghanistan          AFG  Fraction of Children Under 5 Not Stunted, Female
#
#    indicator_code  value  other
# 0     HD.HCI.EYRS  8.580    NaN
# 1  HD.HCI.EYRS.FE  6.730    NaN
# 2  HD.HCI.EYRS.MA  9.210    NaN
# 3     HD.HCI.STNT  0.591    NaN
# 4  HD.HCI.STNT.FE    NaN    NaN

# %%
# полезные колонки надо переименовать

col = ['country_code', 'indicator_code', 'value']

# %%
small_hci_df = hci_df[col]
small_hci_df.head()
# Out:
#   country_code  indicator_code  value
# 0          AFG     HD.HCI.EYRS  8.580
# 1          AFG  HD.HCI.EYRS.FE  6.730
# 2          AFG  HD.HCI.EYRS.MA  9.210
# 3          AFG     HD.HCI.STNT  0.591
# 4          AFG  HD.HCI.STNT.FE    NaN

# %%
# будем строить диаграмму по индикатору HD.HCI.AMRT (Survival Rate from Age 15-60)

# %%
# отфильтруем по индикатору 'HD.HCI.AMRT'
small_hci_df[small_hci_df['indicator_code'] == "HD.HCI.AMRT"].head()
# Out:
#     country_code indicator_code   value
# 24           AFG    HD.HCI.AMRT  0.7797
# 51           ALB    HD.HCI.AMRT  0.9365
# 78           DZA    HD.HCI.AMRT  0.9070
# 105          AGO    HD.HCI.AMRT  0.7638
# 132          ARG    HD.HCI.AMRT  0.8890

# %%
# Соберем данные для диаграммы просто в списки (выведем первые 5):
small_hci_df[small_hci_df['indicator_code'] == "HD.HCI.AMRT"]['country_code'].tolist()[:5]
# Out:
# ['AFG', 'ALB', 'DZA', 'AGO', 'ARG']

# %%
small_hci_df[small_hci_df['indicator_code'] == "HD.HCI.AMRT"]['value'].tolist()[:5]
# Out:
# [0.7797, 0.9365, 0.907, 0.7638, 0.889]

# %%
#посчитаем количество значений
len(small_hci_df[small_hci_df['indicator_code'] == "HD.HCI.AMRT"]['country_code'].tolist())
# Out:
# 157

# %%
#проверим, равно ли количество значений в двух списках
len(small_hci_df[small_hci_df['indicator_code'] == "HD.HCI.AMRT"]['country_code'].tolist()) == \
    len(small_hci_df[small_hci_df['indicator_code'] == "HD.HCI.AMRT"]['value'].tolist())
# Out:
# True

# %%
#присвоим спискам имена
locations = small_hci_df[small_hci_df['indicator_code'] == "HD.HCI.AMRT"]['country_code'].tolist()
hci_values = small_hci_df[small_hci_df['indicator_code'] == "HD.HCI.AMRT"]['value'].tolist()

# %%
# нанесем на диаграмму
import plotly.plotly as py
import pandas as pd
from plotly.offline import init_notebook_mode, iplot
import plotly
import plotly.graph_objs as go
init_notebook_mode(connected=True)

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_world_gdp_with_codes.csv')

data = [ dict(
        type = 'choropleth',
        locations = locations,
        z = hci_values,
        colorscale = [[0,"rgb(5, 10, 100)"],[0.5,"rgb(70, 100, 200)"],[0.7,"rgb(90, 120, 300)"],\
            [0.8,"rgb(110, 140, 400)"],[0.9,"rgb(130, 160, 500)"],[1,"rgb(220, 220, 600)"]],
        autocolorscale = False,
        reversescale = True,
        marker = dict(
            line = dict (
                #color = 'rgb(180,180,180)',
                color = '#333333',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            #tickprefix = '$',
            color = 'red',
            tickprefix = '',
            title = 'Коэффициент выживаемости'),
      ) ]

layout = dict(
    title = 'Выживаемость в возрасте 15-60 лет в странах мира<br>Источник:\
            <a href="https://datacatalog.worldbank.org/dataset/human-capital-index">\
            Всемирный банк</a>',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)



fig = dict( data=data, layout=layout )
#plotly.offline.plot( fig, filename='Выживаемость в возрасте 15-60 лет в странах мира.html', show_link=False , validate=False) #если надо сохранить html
iplot(fig, filename='1234.html', show_link=False, validate=False);
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# ...

# %%
# Россия выглядит хуже соседей, интересно..
